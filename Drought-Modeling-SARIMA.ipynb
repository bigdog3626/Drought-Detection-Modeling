# %%
# https://www.youtube.com/watch?v=z-uSBE8Pxwg

# %% [markdown]
# SARIMA Modeling
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import itertools
import warnings
warnings.filterwarnings("ignore")

import os
#os.chdir() #need to figure out

# %% [markdown]
# Reading Data

# %%
dataset = pd.read_csv("./Data/WSPIDATA.csv")
dataset.head()
# Out:
#          Date  Precipitation Accumulation  (In)  ...  PRCP_ECDF       SPI
# 0  2008-11-01                               4.9  ...   0.005848 -2.173842
# 1  2008-11-02                               4.9  ...   0.005848 -2.173842
# 2  2008-11-03                               4.9  ...   0.005848 -2.173842
# 3  2008-11-04                               4.9  ...   0.005848 -2.173842
# 4  2008-11-05                               4.9  ...   0.005848 -2.173842
#
# [5 rows x 29 columns]

# %%
date = np.array(dataset['Date']) # Date Array
